# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import nn, optim
from torch.autograd import Variable

from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import precision_score, recall_score, roc_auc_score

from table_evaluator import TableEvaluator

from sklearn.utils._testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning

import os.path, sys
from tests.utils import load_adult

import warnings

# synthcity absolute
import synthcity.logger as log
from synthcity.plugins import Plugins
from synthcity.plugins.core.dataloader import GenericDataLoader
# Out:
# [KeOps] Warning :
#     The default C++ compiler could not be found on your system.
#     You need to either define the CXX environment variable or a symlink to the g++ command.
#     For example if g++-8 is the command you can do
#       import os
#       os.environ['CXX'] = 'g++-8'
#
# [KeOps] Warning : Cuda libraries were not detected on the system ; using cpu only mode

# %%
log.add(sink=sys.stderr, level="INFO")
sys.path.append(os.getcwd())

# %%
import PreProcessData

clean_df = PreProcessData.clean_df('data/adult.data')
#arr_X, arr_y, adult_df = load_adult() # arr_X np array without label/target, arr_y np array of just label/target

clean_df
# Out:
#        race  age  sex  native-country  marital-status  education  occupation  \
# 0         0   39    1               0               2          0           8
# 1         0   50    1               0               0          0           4
# 2         0   38    1               0               1          3           6
# 3         4   53    1               0               0          2           6
# 4         4   28    0              12               0          0           5
# ...     ...  ...  ...             ...             ...        ...         ...
# 32556     0   27    0               0               0          5           0
# 32557     0   40    1               0               0          3           7
# 32558     0   58    0               0               4          3           8
# 32559     0   22    1               0               2          3           8
# 32560     0   52    0               0               0          3           4
#
#        hours-per-week  workclass  relationship  label
# 0                  40          5             3      1
# 1                  13          1             2      1
# 2                  40          0             3      1
# 3                  40          0             2      1
# 4                  40          0             0      1
# ...               ...        ...           ...    ...
# 32556              38          0             0      1
# 32557              40          0             2      0
# 32558              40          0             5      1
# 32559              20          0             1      1
# 32560              40          2             0      0
#
# [30162 rows x 11 columns]

# %%
loader = GenericDataLoader(
    clean_df,
    target_column="label",
    sensitive_columns=["race","sex","native-country"],
)

loader
# Out:
#        race  age  sex  native-country  marital-status  education  occupation  \
# 0         0   39    1               0               2          0           8
# 1         0   50    1               0               0          0           4
# 2         0   38    1               0               1          3           6
# 3         4   53    1               0               0          2           6
# 4         4   28    0              12               0          0           5
# ...     ...  ...  ...             ...             ...        ...         ...
# 32556     0   27    0               0               0          5           0
# 32557     0   40    1               0               0          3           7
# 32558     0   58    0               0               4          3           8
# 32559     0   22    1               0               2          3           8
# 32560     0   52    0               0               0          3           4
#
#        hours-per-week  workclass  relationship  label
# 0                  40          5             3      1
# 1                  13          1             2      1
# 2                  40          0             3      1
# 3                  40          0             2      1
# 4                  40          0             0      1
# ...               ...        ...           ...    ...
# 32556              38          0             0      1
# 32557              40          0             2      0
# 32558              40          0             5      1
# 32559              20          0             1      1
# 32560              40          2             0      0
#
# [30162 rows x 11 columns]

# %%
# synthcity absolute
from synthcity.plugins import Plugins
from synthcity.plugins.privacy import plugin_dpgan

#syn_model = Plugins().get("dpgan")

syn_model = plugin_dpgan.DPGANPlugin(n_iter = 10, n_iter_min=1)

syn_model.fit(loader)
# Out:
# [2023-12-05T16:18:54.907739-0600][16324][INFO] Encoding race 3843332182083652118
# [2023-12-05T16:18:54.907739-0600][16324][INFO] Encoding age 42226137574194105
# [2023-12-05T16:18:56.854956-0600][16324][INFO] Encoding sex 7310119158062436415
# [2023-12-05T16:18:56.871456-0600][16324][INFO] Encoding native-country 6190545641124984424
# [2023-12-05T16:18:58.637670-0600][16324][INFO] Encoding marital-status 1207444760813777779
# [2023-12-05T16:18:58.637670-0600][16324][INFO] Encoding education 7923692313984985242
# [2023-12-05T16:19:01.086982-0600][16324][INFO] Encoding occupation 2060381146028151082
# [2023-12-05T16:19:03.022476-0600][16324][INFO] Encoding hours-per-week 1474711948381798600
# [2023-12-05T16:19:04.189262-0600][16324][INFO] Encoding workclass 6611077038566673260
# [2023-12-05T16:19:04.203080-0600][16324][INFO] Encoding relationship 163436197888038013
# [2023-12-05T16:19:04.209106-0600][16324][INFO] Encoding label 5779905084709826269
# [2023-12-05T16:19:05.082095-0600][16324][INFO] Training GAN on device cpu. features = 59
# 100%|██████████| 10/10 [17:30<00:00, 105.08s/it]

# %%
synth_df = syn_model.generate(count=75000).dataframe()
synth_df
# Out:
#        race  age  sex  native-country  marital-status  education  occupation  \
# 0         2   17    0              26               6          8           6
# 1         2   17    0              26               5          8           9
# 2         2   17    0              40               6          6           9
# 3         4   32    0              40               6          6           5
# 4         1   17    0              25               3          6          10
# ...     ...  ...  ...             ...             ...        ...         ...
# 74995     2   18    0              40               5          8           7
# 74996     2   17    0              40               6          8           5
# 74997     2   20    0              26               4          8           9
# 74998     1   19    1              22               6          6           8
# 74999     2   17    0              12               6          6           6
#
#        hours-per-week  workclass  relationship  label
# 0                  57          1             0      0
# 1                  57          6             0      1
# 2                  57          6             0      1
# 3                  57          6             5      0
# 4                  57          5             0      1
# ...               ...        ...           ...    ...
# 74995              57          6             4      1
# 74996               1          1             5      0
# 74997               1          6             0      0
# 74998              16          6             0      0
# 74999               3          6             0      0
#
# [75000 rows x 11 columns]

# %%
from Metrics import get_metrics

get_metrics("DP-None", clean_df, synth_df)
# Out:
# Statistics for dataset for mode: DP-None
# Precision: 0.4333269635008599
# Recall: 0.9910839160839161
# AUROC: 0.499190860023747
# FTU: 0.00728
# DP: 0.015998434447435872

# %%
# synthcity absolute
# from SynthBenchmarks import Benchmarks

from synthcity.benchmark import Benchmarks

score = Benchmarks.evaluate(
    [(f"test_eps_{eps}", "dpgan", {"epsilon": eps, "n_iter": 10, "n_iter_min": 1}) for eps in [0.1]],
    loader,
    synthetic_size=1000,
    repeats=2
)
# score = Benchmarks.evaluate(
#     [(f"test_eps_{eps}", "dpgan", {"epsilon": eps}) for eps in [0.1, 1, 10]],
#     loader,
#     synthetic_size=1000,
#     repeats=2,
#     #synthetic_cache=False
#     #synthetic_reuse_if_exists=True
# )
# Out:
# [2023-12-05T17:46:53.084164-0600][2640][INFO] Testcase : test_eps_0.1
# [2023-12-05T17:46:53.086162-0600][2640][INFO] [testcase] Experiment repeat: 0 task type: classification Train df hash = 8844315381081027915
# [2023-12-05T17:47:11.497119-0600][2640][INFO] Encoding race 8839838288685913191
# [2023-12-05T17:47:11.511757-0600][2640][INFO] Encoding age 7983650266753259497
# [2023-12-05T17:47:12.754385-0600][2640][INFO] Encoding sex 4570725880838915145
# [2023-12-05T17:47:12.757999-0600][2640][INFO] Encoding native-country 7154188036210242214
# [2023-12-05T17:47:13.875947-0600][2640][INFO] Encoding marital-status 9060001245496613666
# [2023-12-05T17:47:13.875947-0600][2640][INFO] Encoding education 4958767644402141762
# [2023-12-05T17:47:14.705408-0600][2640][INFO] Encoding occupation 7487045939440258640
# [2023-12-05T17:47:15.871829-0600][2640][INFO] Encoding hours-per-week 54294204929279679
# [2023-12-05T17:47:16.670592-0600][2640][INFO] Encoding workclass 4227416048796935791
# [2023-12-05T17:47:16.676615-0600][2640][INFO] Encoding relationship 5307621220283089396
# [2023-12-05T17:47:16.681590-0600][2640][INFO] Encoding label 426742775345651831
# [2023-12-05T17:47:17.372721-0600][2640][INFO] Training GAN on device cpu. features = 59
# 100%|██████████| 10/10 [14:56<00:00, 89.68s/it]
# [2023-12-05T18:02:16.486965-0600][2640][ERROR]  >> Evaluator stats.survival_km_distance failed: The metric is valid only for survival analysis tasks, but got classification
# [2023-12-05T18:02:16.503160-0600][2640][ERROR]  >> Evaluator stats.fid failed: The metric is valid only for image tasks, but got datasets generic and generic
# [2023-12-05T18:02:42.442935-0600][2640][INFO]  Feature Importance rank distance df hash = 5322395195854323148 ood hash = 6676934361353939976. score = {'corr': 0.16761771886126822, 'pvalue': 0.0004263469506177795}
# [2023-12-05T18:02:42.592078-0600][2640][INFO]  Synthetic-real data discrimination using detection_xgb. AUCROC : {'mean': 0.9999099997301792}
# [2023-12-05T18:02:48.836159-0600][2640][INFO]  Synthetic-real data discrimination using detection_mlp. AUCROC : {'mean': 0.9665546982309854}
# [2023-12-05T18:02:49.300497-0600][2640][INFO]  Synthetic-real data discrimination using detection_gmm. AUCROC : {'mean': 0.42259785994838417}
# [2023-12-05T18:02:51.653733-0600][2640][INFO]  Synthetic-real data discrimination using detection_linear. AUCROC : {'mean': 0.999465587397831}
# [2023-12-05T18:10:01.161547-0600][2640][ERROR]  >> Evaluator privacy.DomiasMIA_KDE failed: Number of dimensions is greater than number of samples. This results in a singular data covariance matrix, which cannot be treated using the algorithms implemented in `gaussian_kde`. Note that `gaussian_kde` interprets each *column* of `dataset` to be a point; consider transposing the input to `dataset`.
# [2023-12-05T18:10:03.164748-0600][2640][INFO] [testcase] Experiment repeat: 1 task type: classification Train df hash = 8844315381081027915
# [2023-12-05T18:10:03.596644-0600][2640][INFO] Encoding race 8839838288685913191
# [2023-12-05T18:10:03.627898-0600][2640][INFO] Encoding age 7983650266753259497
# [2023-12-05T18:10:04.644693-0600][2640][INFO] Encoding sex 4570725880838915145
# [2023-12-05T18:10:04.644693-0600][2640][INFO] Encoding native-country 7154188036210242214
# [2023-12-05T18:10:05.641959-0600][2640][INFO] Encoding marital-status 9060001245496613666
# [2023-12-05T18:10:05.661831-0600][2640][INFO] Encoding education 4958767644402141762
# [2023-12-05T18:10:06.430104-0600][2640][INFO] Encoding occupation 7487045939440258640
# [2023-12-05T18:10:07.531546-0600][2640][INFO] Encoding hours-per-week 54294204929279679
# [2023-12-05T18:10:08.325271-0600][2640][INFO] Encoding workclass 4227416048796935791
# [2023-12-05T18:10:08.340898-0600][2640][INFO] Encoding relationship 5307621220283089396
# [2023-12-05T18:10:08.340898-0600][2640][INFO] Encoding label 426742775345651831
# [2023-12-05T18:10:09.111728-0600][2640][INFO] Training GAN on device cpu. features = 59
# 100%|██████████| 10/10 [15:00<00:00, 90.09s/it]
# [2023-12-05T18:25:12.951760-0600][2640][ERROR]  >> Evaluator stats.survival_km_distance failed: The metric is valid only for survival analysis tasks, but got classification
# [2023-12-05T18:25:12.951760-0600][2640][ERROR]  >> Evaluator stats.fid failed: The metric is valid only for image tasks, but got datasets generic and generic
# [2023-12-05T18:25:35.704642-0600][2640][INFO]  Feature Importance rank distance df hash = 5322395195854323148 ood hash = 6676934361353939976. score = {'corr': 0.09644670062942401, 'pvalue': 0.04257183784186447}
# [2023-12-05T18:25:35.825070-0600][2640][INFO]  Synthetic-real data discrimination using detection_xgb. AUCROC : {'mean': 0.9998378465138638}
# [2023-12-05T18:25:40.355966-0600][2640][INFO]  Synthetic-real data discrimination using detection_mlp. AUCROC : {'mean': 0.9641939146533561}
# [2023-12-05T18:25:40.774420-0600][2640][INFO]  Synthetic-real data discrimination using detection_gmm. AUCROC : {'mean': 0.5555004528903579}
# [2023-12-05T18:25:43.771214-0600][2640][INFO]  Synthetic-real data discrimination using detection_linear. AUCROC : {'mean': 0.991008073042203}
# [2023-12-05T18:32:09.721788-0600][2640][ERROR]  >> Evaluator privacy.DomiasMIA_KDE failed: Number of dimensions is greater than number of samples. This results in a singular data covariance matrix, which cannot be treated using the algorithms implemented in `gaussian_kde`. Note that `gaussian_kde` interprets each *column* of `dataset` to be a point; consider transposing the input to `dataset`.

# %%
Benchmarks.print(score)
# Out:
# Plugin : test_eps_0.1
#                                                          min        max  \
# sanity.data_mismatch.score                          0.583333   0.583333
# sanity.common_rows_proportion.score                 0.000000   0.000000
# sanity.nearest_syn_neighbor_distance.mean           0.167348   0.171346
# sanity.close_values_probability.score               0.716000   0.744000
# sanity.distant_values_probability.score             0.001000   0.003000
# stats.jensenshannon_dist.marginal                   0.072213   0.084152
# stats.chi_squared_test.marginal                     0.090169   0.102270
# stats.inv_kl_divergence.marginal                    0.431634   0.451789
# stats.ks_test.marginal                              0.386455   0.465273
# stats.max_mean_discrepancy.joint                    0.002181   0.002228
# stats.wasserstein_dist.joint                        0.692223   0.985211
# stats.prdc.precision                                0.735000   0.870000
# stats.prdc.recall                                   0.332000   0.356000
# stats.prdc.density                                  0.278200   0.411400
# stats.prdc.coverage                                 0.112000   0.143000
# stats.alpha_precision.delta_precision_alpha_OC      0.219333   0.852593
# stats.alpha_precision.delta_coverage_beta_OC        0.057600   0.094933
# stats.alpha_precision.authenticity_OC               0.874000   0.936000
# stats.alpha_precision.delta_precision_alpha_naive   0.288540   0.295936
# stats.alpha_precision.delta_coverage_beta_naive     0.004867   0.031133
# stats.alpha_precision.authenticity_naive            0.995000   0.997000
# performance.linear_model.gt                         0.836426   0.836426
# performance.linear_model.syn_id                     0.486205   0.722643
# performance.linear_model.syn_ood                    0.506382   0.614555
# performance.mlp.gt                                  0.500000   0.500000
# performance.mlp.syn_id                              0.500000   0.693847
# performance.mlp.syn_ood                             0.500000   0.652849
# performance.xgb.gt                                  0.838320   0.838320
# performance.xgb.syn_id                              0.555172   0.594377
# performance.xgb.syn_ood                             0.526582   0.567246
# performance.linear_model_augmentation.gt            0.836426   0.836426
# performance.linear_model_augmentation.aug_ood       0.506382   0.614555
# performance.mlp_augmentation.gt                     0.500000   0.500000
# performance.mlp_augmentation.aug_ood                0.500000   0.652849
# performance.xgb_augmentation.gt                     0.838320   0.838320
# performance.xgb_augmentation.aug_ood                0.526582   0.567246
# performance.feat_rank_distance.corr                 0.096447   0.167618
# performance.feat_rank_distance.pvalue               0.000426   0.042572
# detection.detection_xgb.mean                        0.999838   0.999910
# detection.detection_mlp.mean                        0.964194   0.966555
# detection.detection_gmm.mean                        0.422598   0.555500
# detection.detection_linear.mean                     0.991008   0.999466
# privacy.delta-presence.score                       17.181818  19.142857
# privacy.k-anonymization.gt                          8.000000   8.000000
# privacy.k-anonymization.syn                         7.000000  20.000000
# privacy.k-map.score                                 2.000000   3.000000
# privacy.distinct l-diversity.gt                     8.000000   8.000000
# privacy.distinct l-diversity.syn                    7.000000  20.000000
# privacy.identifiability_score.score                 0.034000   0.037000
# privacy.identifiability_score.score_OC              0.064000   0.089000
# privacy.DomiasMIA_BNAF.accuracy                     0.499896   0.499979
# privacy.DomiasMIA_BNAF.aucroc                       0.470668   0.496620
# privacy.DomiasMIA_prior.accuracy                    0.499979   0.499979
# privacy.DomiasMIA_prior.aucroc                      0.485633   0.525179
#
#                                                         mean    stddev  \
# sanity.data_mismatch.score                          0.583333  0.000000
# sanity.common_rows_proportion.score                 0.000000  0.000000
# sanity.nearest_syn_neighbor_distance.mean           0.169347  0.001999
# sanity.close_values_probability.score               0.730000  0.014000
# sanity.distant_values_probability.score             0.002000  0.001000
# stats.jensenshannon_dist.marginal                   0.078182  0.005969
# stats.chi_squared_test.marginal                     0.096219  0.006051
# stats.inv_kl_divergence.marginal                    0.441711  0.010078
# stats.ks_test.marginal                              0.425864  0.039409
# stats.max_mean_discrepancy.joint                    0.002204  0.001000
# stats.wasserstein_dist.joint                        0.838717  0.146494
# stats.prdc.precision                                0.802500  0.067500
# stats.prdc.recall                                   0.344000  0.012000
# stats.prdc.density                                  0.344800  0.066600
# stats.prdc.coverage                                 0.127500  0.015500
# stats.alpha_precision.delta_precision_alpha_OC      0.535963  0.316630
# stats.alpha_precision.delta_coverage_beta_OC        0.076267  0.018667
# stats.alpha_precision.authenticity_OC               0.905000  0.031000
# stats.alpha_precision.delta_precision_alpha_naive   0.292238  0.003698
# stats.alpha_precision.delta_coverage_beta_naive     0.018000  0.013133
# stats.alpha_precision.authenticity_naive            0.996000  0.001000
# performance.linear_model.gt                         0.836426  0.000000
# performance.linear_model.syn_id                     0.604424  0.118219
# performance.linear_model.syn_ood                    0.560468  0.054086
# performance.mlp.gt                                  0.500000  0.000000
# performance.mlp.syn_id                              0.596924  0.096924
# performance.mlp.syn_ood                             0.576425  0.076425
# performance.xgb.gt                                  0.838320  0.000000
# performance.xgb.syn_id                              0.574775  0.019603
# performance.xgb.syn_ood                             0.546914  0.020332
# performance.linear_model_augmentation.gt            0.836426  0.000000
# performance.linear_model_augmentation.aug_ood       0.560468  0.054086
# performance.mlp_augmentation.gt                     0.500000  0.000000
# performance.mlp_augmentation.aug_ood                0.576425  0.076425
# performance.xgb_augmentation.gt                     0.838320  0.000000
# performance.xgb_augmentation.aug_ood                0.546914  0.020332
# performance.feat_rank_distance.corr                 0.132032  0.035586
# performance.feat_rank_distance.pvalue               0.021499  0.021073
# detection.detection_xgb.mean                        0.999874  0.001000
# detection.detection_mlp.mean                        0.965374  0.001180
# detection.detection_gmm.mean                        0.489049  0.066451
# detection.detection_linear.mean                     0.995237  0.004229
# privacy.delta-presence.score                       18.162338  0.980519
# privacy.k-anonymization.gt                          8.000000  0.000000
# privacy.k-anonymization.syn                        13.500000  6.500000
# privacy.k-map.score                                 2.500000  0.500000
# privacy.distinct l-diversity.gt                     8.000000  0.000000
# privacy.distinct l-diversity.syn                   13.500000  6.500000
# privacy.identifiability_score.score                 0.035500  0.001500
# privacy.identifiability_score.score_OC              0.076500  0.012500
# privacy.DomiasMIA_BNAF.accuracy                     0.499938  0.001000
# privacy.DomiasMIA_BNAF.aucroc                       0.483644  0.012976
# privacy.DomiasMIA_prior.accuracy                    0.499979  0.000000
# privacy.DomiasMIA_prior.aucroc                      0.505406  0.019773
#
#                                                       median       iqr rounds  \
# sanity.data_mismatch.score                          0.583333  0.000000      2
# sanity.common_rows_proportion.score                 0.000000  0.000000      2
# sanity.nearest_syn_neighbor_distance.mean           0.169347  0.001999      2
# sanity.close_values_probability.score               0.730000  0.014000      2
# sanity.distant_values_probability.score             0.002000  0.001000      2
# stats.jensenshannon_dist.marginal                   0.078182  0.005969      2
# stats.chi_squared_test.marginal                     0.096219  0.006051      2
# stats.inv_kl_divergence.marginal                    0.441711  0.010078      2
# stats.ks_test.marginal                              0.425864  0.039409      2
# stats.max_mean_discrepancy.joint                    0.002204  0.000024      2
# stats.wasserstein_dist.joint                        0.838717  0.146494      2
# stats.prdc.precision                                0.802500  0.067500      2
# stats.prdc.recall                                   0.344000  0.012000      2
# stats.prdc.density                                  0.344800  0.066600      2
# stats.prdc.coverage                                 0.127500  0.015500      2
# stats.alpha_precision.delta_precision_alpha_OC      0.535963  0.316630      2
# stats.alpha_precision.delta_coverage_beta_OC        0.076267  0.018667      2
# stats.alpha_precision.authenticity_OC               0.905000  0.031000      2
# stats.alpha_precision.delta_precision_alpha_naive   0.292238  0.003698      2
# stats.alpha_precision.delta_coverage_beta_naive     0.018000  0.013133      2
# stats.alpha_precision.authenticity_naive            0.996000  0.001000      2
# performance.linear_model.gt                         0.836426  0.000000      2
# performance.linear_model.syn_id                     0.604424  0.118219      2
# performance.linear_model.syn_ood                    0.560468  0.054086      2
# performance.mlp.gt                                  0.500000  0.000000      2
# performance.mlp.syn_id                              0.596924  0.096924      2
# performance.mlp.syn_ood                             0.576425  0.076425      2
# performance.xgb.gt                                  0.838320  0.000000      2
# performance.xgb.syn_id                              0.574775  0.019603      2
# performance.xgb.syn_ood                             0.546914  0.020332      2
# performance.linear_model_augmentation.gt            0.836426  0.000000      2
# performance.linear_model_augmentation.aug_ood       0.560468  0.054086      2
# performance.mlp_augmentation.gt                     0.500000  0.000000      2
# performance.mlp_augmentation.aug_ood                0.576425  0.076425      2
# performance.xgb_augmentation.gt                     0.838320  0.000000      2
# performance.xgb_augmentation.aug_ood                0.546914  0.020332      2
# performance.feat_rank_distance.corr                 0.132032  0.035586      2
# performance.feat_rank_distance.pvalue               0.021499  0.021073      2
# detection.detection_xgb.mean                        0.999874  0.000036      2
# detection.detection_mlp.mean                        0.965374  0.001180      2
# detection.detection_gmm.mean                        0.489049  0.066451      2
# detection.detection_linear.mean                     0.995237  0.004229      2
# privacy.delta-presence.score                       18.162338  0.980519      2
# privacy.k-anonymization.gt                          8.000000  0.000000      2
# privacy.k-anonymization.syn                        13.500000  6.500000      2
# privacy.k-map.score                                 2.500000  0.500000      2
# privacy.distinct l-diversity.gt                     8.000000  0.000000      2
# privacy.distinct l-diversity.syn                   13.500000  6.500000      2
# privacy.identifiability_score.score                 0.035500  0.001500      2
# privacy.identifiability_score.score_OC              0.076500  0.012500      2
# privacy.DomiasMIA_BNAF.accuracy                     0.499938  0.000041      2
# privacy.DomiasMIA_BNAF.aucroc                       0.483644  0.012976      2
# privacy.DomiasMIA_prior.accuracy                    0.499979  0.000000      2
# privacy.DomiasMIA_prior.aucroc                      0.505406  0.019773      2
#
#                                                   errors  durations
# sanity.data_mismatch.score                             0       0.00
# sanity.common_rows_proportion.score                    0       0.00
# sanity.nearest_syn_neighbor_distance.mean              0       0.01
# sanity.close_values_probability.score                  0       0.01
# sanity.distant_values_probability.score                0       0.00
# stats.jensenshannon_dist.marginal                      0       0.08
# stats.chi_squared_test.marginal                        0       0.01
# stats.inv_kl_divergence.marginal                       0       0.02
# stats.ks_test.marginal                                 0       0.02
# stats.max_mean_discrepancy.joint                       0       0.11
# stats.wasserstein_dist.joint                           0       0.70
# stats.prdc.precision                                   0       0.08
# stats.prdc.recall                                      0       0.08
# stats.prdc.density                                     0       0.08
# stats.prdc.coverage                                    0       0.08
# stats.alpha_precision.delta_precision_alpha_OC         0       0.36
# stats.alpha_precision.delta_coverage_beta_OC           0       0.36
# stats.alpha_precision.authenticity_OC                  0       0.36
# stats.alpha_precision.delta_precision_alpha_naive      0       0.36
# stats.alpha_precision.delta_coverage_beta_naive        0       0.36
# stats.alpha_precision.authenticity_naive               0       0.36
# performance.linear_model.gt                            0       0.40
# performance.linear_model.syn_id                        0       0.40
# performance.linear_model.syn_ood                       0       0.40
# performance.mlp.gt                                     0      10.60
# performance.mlp.syn_id                                 0      10.60
# performance.mlp.syn_ood                                0      10.60
# performance.xgb.gt                                     0       1.13
# performance.xgb.syn_id                                 0       1.13
# performance.xgb.syn_ood                                0       1.13
# performance.linear_model_augmentation.gt               0       0.36
# performance.linear_model_augmentation.aug_ood          0       0.36
# performance.mlp_augmentation.gt                        0      10.56
# performance.mlp_augmentation.aug_ood                   0      10.56
# performance.xgb_augmentation.gt                        0       0.82
# performance.xgb_augmentation.aug_ood                   0       0.82
# performance.feat_rank_distance.corr                    0       0.49
# performance.feat_rank_distance.pvalue                  0       0.49
# detection.detection_xgb.mean                           0       0.14
# detection.detection_mlp.mean                           0       5.38
# detection.detection_gmm.mean                           0       0.49
# detection.detection_linear.mean                        0       2.62
# privacy.delta-presence.score                           0       0.14
# privacy.k-anonymization.gt                             0       0.31
# privacy.k-anonymization.syn                            0       0.31
# privacy.k-map.score                                    0       0.14
# privacy.distinct l-diversity.gt                        0       0.51
# privacy.distinct l-diversity.syn                       0       0.51
# privacy.identifiability_score.score                    0       0.12
# privacy.identifiability_score.score_OC                 0       0.12
# privacy.DomiasMIA_BNAF.accuracy                        0     406.29
# privacy.DomiasMIA_BNAF.aucroc                          0     406.29
# privacy.DomiasMIA_prior.accuracy                       0       1.36
# privacy.DomiasMIA_prior.aucroc                         0       1.36
